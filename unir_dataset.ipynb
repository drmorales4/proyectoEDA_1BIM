# %% [markdown]
# # Dataset final

# %%
# Importar librerias
import pandas as pd
import numpy as np
import csv
from datetime import datetime
import seaborn as sb
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import plotly.express as px
import plotly.graph_objects as go
import matplotlib

# %%
datagit = pd.read_csv('data/datosgithub.csv', sep=','); #Lectura del csv

# %%
datakaggle = pd.read_csv('data/datosKaggle.csv', sep=','); #Lectura del csv

# %%
datagit.head()
# Out:
#    country        date  Confirmed  Deaths  Recovered   Active  Incident_Rate  \
# 0  Ecuador  2021-05-02     384589   18724   318598.0  47267.0    2179.831617
# 1  Ecuador  2021-05-03     387299   18740   329582.0  38977.0    2195.191764
# 2  Ecuador  2021-05-04     388046   18765   329582.0  39699.0    2199.425723
# 3  Ecuador  2021-05-05     391242   18863   329582.0  42797.0    2217.540495
# 4  Ecuador  2021-05-06     393048   18907   329582.0  44559.0    2227.776814
#
#    Case_Fatality_Ratio
# 0             4.868574
# 1             4.838639
# 2             4.835767
# 3             4.821313
# 4             4.810354

# %%
datakaggle.head()
# Out:
#    country        date  total_vaccinations  people_vaccinated  \
# 0  Ecuador  2021-05-02           1067472.0           821960.0
# 1  Ecuador  2021-05-03                 NaN                NaN
# 2  Ecuador  2021-05-04           1141262.0           889218.0
# 3  Ecuador  2021-05-05           1182085.0           924539.0
# 4  Ecuador  2021-05-06           1215676.0           953238.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                 245512.0                 30678.0             46219.0
# 1                      NaN                     NaN             48411.0
# 2                 252044.0                     NaN             46441.0
# 3                 257546.0                 40823.0             45813.0
# 4                 262438.0                 33591.0             42116.0
#
#                                        vaccines  \
# 0  Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac
# 1  Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac
# ...

# %%
# Eliminar las columnas 
datakaggle = datakaggle.drop(['country'], axis=1)

# %%
data = pd.merge(datagit, datakaggle, on='date') # unir los 2 dataframe por la variable sourceid en comun y crear nuevo dataframe

# %%
data.head()
# Out:
#    country        date  Confirmed  Deaths  Recovered   Active  Incident_Rate  \
# 0  Ecuador  2021-05-02     384589   18724   318598.0  47267.0    2179.831617
# 1  Ecuador  2021-05-03     387299   18740   329582.0  38977.0    2195.191764
# 2  Ecuador  2021-05-04     388046   18765   329582.0  39699.0    2199.425723
# 3  Ecuador  2021-05-05     391242   18863   329582.0  42797.0    2217.540495
# 4  Ecuador  2021-05-06     393048   18907   329582.0  44559.0    2227.776814
#
#    Case_Fatality_Ratio  total_vaccinations  people_vaccinated  \
# 0             4.868574           1067472.0           821960.0
# 1             4.838639                 NaN                NaN
# 2             4.835767           1141262.0           889218.0
# 3             4.821313           1182085.0           924539.0
# 4             4.810354           1215676.0           953238.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# ## Analisis Bivariado

# %% [markdown]
# ### 1)

# %%
# Diagrama de dispersión
data.plot(kind='scatter', x='total_vaccinations', y='Confirmed')
# Out:
# <AxesSubplot:xlabel='total_vaccinations', ylabel='Confirmed'>

# %%
# Diagrama de dispersión
data.plot(kind='scatter', x='total_vaccinations', y='Deaths')
# Out:
# <AxesSubplot:xlabel='total_vaccinations', ylabel='Deaths'>

# %%
# Diagrama de dispersión
data.plot(kind='scatter', x='people_fully_vaccinated', y='Deaths')
# Out:
# <AxesSubplot:xlabel='people_fully_vaccinated', ylabel='Deaths'>

# %% [markdown]
# ### Matriz de correlación

# %%
plt.rcParams['figure.figsize'] = (15.0, 10.0)  # dimensión
sns.heatmap(data.corr(), annot=True)  # annot_True para presentar el coeficiente de correlación
# Out:
# <AxesSubplot:>
